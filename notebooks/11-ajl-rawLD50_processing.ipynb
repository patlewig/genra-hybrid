# %%
import pandas as pd

df = pd.read_csv('../src/data/raw_LD50.tsv', sep = '\t')
df.head()
# Out:
#       CASRN         DTXSID            Chemical_Name  LD50_mgkg       test_type
# 0  100-00-5  DTXSID5020281  1-Chloro-4-nitrobenzene      294.0  point estimate
# 1  100-00-5  DTXSID5020281  1-Chloro-4-nitrobenzene      420.0  point estimate
# 2  100-00-5  DTXSID5020281  1-Chloro-4-nitrobenzene      500.0  point estimate
# 3  100-00-5  DTXSID5020281  1-Chloro-4-nitrobenzene      530.0  point estimate
# 4  100-00-5  DTXSID5020281  1-Chloro-4-nitrobenzene      565.0  point estimate
